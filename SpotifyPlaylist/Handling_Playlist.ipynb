# %%
import requests
import json
import pandas as pd

data = pd.read_json('playlist_data.json')
data.head(10)
# Out:
#                                  name                                artists
# 0              Emergency Room Complex                  [Chainsaw Castration]
# 1  Heavier than your manga collection  [Yanderechainsawregurgitationfactory]
# 2                 Eyes of Abomination                           [Malodorous]
# 3                    Esophageal Decay                [Parasitic Ejaculation]
# 4                Comfort Rightswiping                              [Gorepot]
# 5                       New Extremity                  [Chainsaw Castration]
# 6                             Dopelow                              [Bodybox]
# 7                               Intro                           [Traumatomy]
# 8                      Adept Genocide                           [Malodorous]
# 9                Cerebral Vivisection                [Parasitic Ejaculation]

# %%
data.dropna(inplace=True)
data.head(10)
# Out:
#                                  name                                artists
# 0              Emergency Room Complex                  [Chainsaw Castration]
# 1  Heavier than your manga collection  [Yanderechainsawregurgitationfactory]
# 2                 Eyes of Abomination                           [Malodorous]
# 3                    Esophageal Decay                [Parasitic Ejaculation]
# 4                Comfort Rightswiping                              [Gorepot]
# 5                       New Extremity                  [Chainsaw Castration]
# 6                             Dopelow                              [Bodybox]
# 7                               Intro                           [Traumatomy]
# 8                      Adept Genocide                           [Malodorous]
# 9                Cerebral Vivisection                [Parasitic Ejaculation]
